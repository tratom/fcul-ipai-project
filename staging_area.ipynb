# %%
import pandas as pd

# %%
df = pd.read_pickle("data_sources/filtered/weather.pkl")
df.head(12)
# Out:
#                                     AccidentID                time  \
# 0   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 00:00:00
# 1   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 01:00:00
# 2   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 02:00:00
# 3   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 03:00:00
# 4   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 04:00:00
# 5   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 05:00:00
# 6   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 06:00:00
# 7   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 07:00:00
# 8   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 08:00:00
# 9   cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 09:00:00
# 10  cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 10:00:00
# 11  cen24la079_2023-12-31_41.610278_-90.588361 2023-12-31 11:00:00
#
#     temperature_2m  relative_humidity_2m  dew_point_2m  pressure_msl  \
# ...

# %%
df = pd.read_pickle("data_sources/filtered/airline.pkl")
df.head(12)

# %%
df = pd.read_pickle("data_sources/filtered/ntsb.pkl")
df["HighestInjury"]
# Out:
# 0           none
# 1           none
# 2          fatal
# 3        serious
# 4           none
#           ...
# 23398       none
# 23399       none
# 23400      fatal
# 23401    serious
# 23402      fatal
# Name: HighestInjury, Length: 23403, dtype: category
# Categories (4, object): ['fatal', 'minor', 'none', 'serious']
